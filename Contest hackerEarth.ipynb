# %% [markdown]
# <a href="https://colab.research.google.com/github/ibrezm1/MultilayerKeras/blob/master/Contest%20hackerEarth.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('train.csv')

# %%
df.describe()
# Out:
#        Allied_Nations  Diplomatic_Meetings_Set  ...  DEFCON_Level            ID
# count    10000.000000             10000.000000  ...  10000.000000  10000.000000
# mean         8.317800                 0.524100  ...      2.616600   6266.554200
# std          1.748802                 0.500244  ...      0.802788   3610.170288
# min          5.000000                 0.000000  ...      1.000000      2.000000
# 25%          7.000000                 0.000000  ...      2.000000   3139.750000
# 50%          8.000000                 1.000000  ...      3.000000   6280.500000
# 75%          9.000000                 1.000000  ...      3.000000   9391.500000
# max         16.000000                 2.000000  ...      5.000000  12500.000000
#
# [8 rows x 12 columns]

# %%
df.corr(method ='pearson')
# Out:
#                               Allied_Nations  ...        ID
# Allied_Nations                      1.000000  ...  0.003590
# Diplomatic_Meetings_Set            -0.278779  ...  0.014537
# Percent_Of_Forces_Mobilized         0.650308  ... -0.005668
# Hostile_Nations                     0.111896  ... -0.007541
# Active_Threats                     -0.113609  ...  0.006807
# Inactive_Threats                   -0.067496  ... -0.000820
# Citizen_Fear_Index                  0.647604  ...  0.000119
# Closest_Threat_Distance(km)        -0.668521  ...  0.010935
# Aircraft_Carriers_Responding        0.096352  ...  0.001647
# Troops_Mobilized(thousands)        -0.110071  ...  0.002800
# DEFCON_Level                        0.060440  ...  0.012382
# ID                                  0.003590  ...  1.000000
#
# [12 rows x 12 columns]

# %%
import seaborn as sn
corrMatrix = df.corr()
import matplotlib.pyplot as plt
plt.subplots(figsize=(10,10))
sn.heatmap(corrMatrix, annot=True)

# %%
df['act_by_allied']= df.Active_Threats/df.Allied_Nations

# %%
corrMatrix = df.corr()
import matplotlib.pyplot as plt
plt.subplots(figsize=(10,10))
sn.heatmap(corrMatrix, annot=True)
